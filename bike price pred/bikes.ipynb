# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('BIKE DETAILS.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1061 entries, 0 to 1060
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1061 non-null   object
#  1   selling_price      1061 non-null   int64
#  2   year               1061 non-null   int64
#  3   seller_type        1061 non-null   object
#  4   owner              1061 non-null   object
#  5   km_driven          1061 non-null   int64
#  6   ex_showroom_price  626 non-null    float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 58.1+ KB

# %%
df.shape
# Out:
# (1061, 7)

# %%
df.isna().sum()
# Out:
# name                   0
# selling_price          0
# year                   0
# seller_type            0
# owner                  0
# km_driven              0
# ex_showroom_price    435
# dtype: int64

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\nihar\AppData\Local\Temp\ipykernel_20880\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <AxesSubplot: >

# %%
df.sample(10)
# Out:
#                                             name  selling_price  year  \
# 760                                    Honda Dio          50000  2016
# 158                             Yamaha Saluto RX          40000  2017
# 66                                     Hero Hunk          45000  2014
# 388                             Bajaj Pulsar 150           8000  2005
# 584                             Bajaj Pulsar 150          68000  2019
# 866   Royal Enfield Continental GT [2013 - 2018]         110000  2014
# 579                            Yamaha FZ S V 2.0          80000  2019
# 886                                    Honda Dio          60000  2018
# 1017                           Yamaha FZ S V 2.0          48000  2017
# 343                               Hero HF Deluxe          35000  2017
#
#      seller_type      owner  km_driven  ex_showroom_price
# 760   Individual  1st owner       8000                NaN
# 158   Individual  1st owner      27000            49521.0
# ...

# %%
bikes = df['name'].unique()

# %%
sns.pairplot(data = df )

# %%
data2 = df.copy()
data2['ex_showroom_price'] = data2['ex_showroom_price'].fillna(data2['ex_showroom_price'].median())

# %%
sns.pairplot(data = data2)

# %%
df.drop('km_driven',inplace = True,axis =1)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['name'] = le.fit_transform(df['name'])

# %%
bikes_label = df['name'].unique()

# %%
dic = dict()

for i in range(len(bikes)):
    dic[bikes[i]] = bikes_label[i]

# %%
dic
# Out:
# {'Royal Enfield Classic 350': 179,
#  'Honda Dio': 145,
#  'Royal Enfield Classic Gunmetal Grey': 183,
#  'Yamaha Fazer FI V 2.0 [2016-2018]': 260,
#  'Yamaha SZ [2013-2014]': 269,
#  'Honda CB Twister': 135,
#  'Honda CB Hornet 160R': 131,
#  'Royal Enfield Bullet 350 [2007-2011]': 177,
#  'Hero Honda CBZ extreme': 73,
#  'Bajaj Discover 125': 21,
#  'Yamaha FZ16': 254,
#  'Honda Navi': 152,
#  'Bajaj Avenger Street 220': 12,
#  'Yamaha YZF R3': 277,
#  'Jawa 42': 157,
#  'Suzuki Access 125 [2007-2016]': 202,
#  'Hero Honda Glamour': 77,
#  'Yamaha YZF R15 S': 274,
#  'Yamaha FZ25': 255,
#  'Hero Passion Pro 110': 102,
#  'Honda Navi [2016-2017]': 153,
#  'Honda Activa i': 128,
#  'Jawa Standard': 158,
#  'Royal Enfield Thunderbird 350': 197,
#  'Honda Dream Yuga': 147,
#  'TVS Apache RTR 160 4V': 215,
#  'Yamaha Fazer [2009-2016]': 261,
#  'Hero Honda Splendor NXG': 87,
#  'Hero Glamour 125': 67,
#  'Yamaha FZ S [2012-2016]': 252,
#  'Hero Xtreme Sports': 120,
# ...

# %%
df.dropna(inplace = True)

# %%
df.drop(columns = ['seller_type','owner'],inplace = True)

# %%
df

# %%
import pickle

# %%
pickle.dump(df.to_dict(),open("bikes.pkl","wb"))

# %%
dic

# %%
df['year'].unique()
# Out:
# array([2019, 2017, 2018, 2015, 2011, 2010, 2008, 2016, 2020, 2012, 2006,
#        2013, 2009, 2014, 2004, 2007, 2000, 2002, 2005, 1997, 2001, 1988,
#        1999, 1998, 1991, 2003, 1993, 1995], dtype=int64)

# %%
k = [2019, 2017, 2018, 2015, 2011, 2010, 2008, 2016, 2020, 2012, 2006,
       2013, 2009, 2014, 2004, 2007, 2000, 2002, 2005, 1997, 2001, 1988,
       1999, 1998, 1991, 2003, 1993, 1995]

# %%
k.reverse()

# %%
print(k)
# Out:
# [1995, 1993, 2003, 1991, 1998, 1999, 1988, 2001, 1997, 2005, 2002, 2000, 2007, 2004, 2014, 2009, 2013, 2006, 2012, 2020, 2016, 2008, 2010, 2011, 2015, 2018, 2017, 2019]

# %%
np.max(df['ex_showroom_price'].dropna().values)
# Out:
# 1278000.0
